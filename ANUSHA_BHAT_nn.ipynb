# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
#from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense, Dropout
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from keras.utils.np_utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow.keras.preprocessing.image import load_img
from keras.utils import to_categorical

import os

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2246
# 118

# %% [markdown]
# **Load using keras.preprocessing**
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.
#
# **Create a dataset**
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2246 files belonging to 9 classes.
# Using 1797 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2246 files belonging to 9 classes.
# Using 449 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# **Visualize the data**
#
# Create a code to visualize one instance of all the nine classes present in the dataset

# %%
#Visualize one instance of all the class present in the dataset.

#image_dataset_from_directory() will return a tf.data.Dataset that yields batches of images from the subdirectories.
#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes), representing a one-hot encoding of the class index.
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),
                                                                    label_mode='categorical',seed=123)

#all the classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))
    
#Visualize image 
plt.figure(figsize=(10,10))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")

#plt.figure(figsize=(10, 10))
#for images, labels in train_ds.take(1):
  #for i in range(9):
    #ax = plt.subplot(3, 3, i + 1)
    #plt.imshow(images[i].numpy().astype("uint8"))
    #plt.title(class_names[labels[i]])
    #plt.axis("off")
# Out:
# Found 2246 files belonging to 9 classes.

# %% [markdown]
# The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.
#
# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch.
#
# Dataset.prefetch() overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Create the model**
#
# Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

# %%
input_shape = (180, 180, 3)

model = Sequential()
model.add(keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))  # Number of classes is 9

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 88, 88, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 64)        18496
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 26,322,793
# Trainable params: 26,322,409
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# **Compile the model**
#
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function


optimizer = 'adam'
loss_fn = "sparse_categorical_crossentropy"
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])


checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 88, 88, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 64)        18496
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 26,322,793
# Trainable params: 26,322,409
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# **Train the model**

# %%
epochs = 20
history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=epochs,
    callbacks=[checkpoint]
    )
# Out:
# Epoch 1/20
# 57/57 [==============================] - ETA: 0s - loss: 25.8049 - accuracy: 0.2894
# Epoch 1: val_accuracy improved from -inf to 0.24053, saving model to model.h5
# 57/57 [==============================] - 328s 1s/step - loss: 25.8049 - accuracy: 0.2894 - val_loss: 8.5705 - val_accuracy: 0.2405
# Epoch 2/20
# 57/57 [==============================] - ETA: 0s - loss: 8.1271 - accuracy: 0.3528
# Epoch 2: val_accuracy did not improve from 0.24053
# 57/57 [==============================] - 3s 61ms/step - loss: 8.1271 - accuracy: 0.3528 - val_loss: 4.3458 - val_accuracy: 0.0646
# Epoch 3/20
# 57/57 [==============================] - ETA: 0s - loss: 2.5753 - accuracy: 0.3111
# Epoch 3: val_accuracy did not improve from 0.24053
# 57/57 [==============================] - 4s 63ms/step - loss: 2.5753 - accuracy: 0.3111 - val_loss: 3.6840 - val_accuracy: 0.1715
# Epoch 4/20
# 57/57 [==============================] - ETA: 0s - loss: 2.0907 - accuracy: 0.3450
# Epoch 4: val_accuracy did not improve from 0.24053
# 57/57 [==============================] - 4s 62ms/step - loss: 2.0907 - accuracy: 0.3450 - val_loss: 2.4600 - val_accuracy: 0.1693
# Epoch 5/20
# 57/57 [==============================] - ETA: 0s - loss: 1.8349 - accuracy: 0.3984
# Epoch 5: val_accuracy improved from 0.24053 to 0.28731, saving model to model.h5
# 57/57 [==============================] - 5s 81ms/step - loss: 1.8349 - accuracy: 0.3984 - val_loss: 2.1695 - val_accuracy: 0.2873
# Epoch 6/20
# 57/57 [==============================] - ETA: 0s - loss: 1.7472 - accuracy: 0.4391
# Epoch 6: val_accuracy did not improve from 0.28731
# 57/57 [==============================] - 3s 61ms/step - loss: 1.7472 - accuracy: 0.4391 - val_loss: 4.2136 - val_accuracy: 0.2138
# Epoch 7/20
# 57/57 [==============================] - ETA: 0s - loss: 1.6748 - accuracy: 0.4341
# Epoch 7: val_accuracy did not improve from 0.28731
# 57/57 [==============================] - 4s 65ms/step - loss: 1.6748 - accuracy: 0.4341 - val_loss: 23.4852 - val_accuracy: 0.1915
# Epoch 8/20
# 57/57 [==============================] - ETA: 0s - loss: 1.6228 - accuracy: 0.4474
# Epoch 8: val_accuracy improved from 0.28731 to 0.31849, saving model to model.h5
# 57/57 [==============================] - 5s 81ms/step - loss: 1.6228 - accuracy: 0.4474 - val_loss: 10.2186 - val_accuracy: 0.3185
# Epoch 9/20
# 57/57 [==============================] - ETA: 0s - loss: 1.5555 - accuracy: 0.4769
# Epoch 9: val_accuracy improved from 0.31849 to 0.33630, saving model to model.h5
# 57/57 [==============================] - 5s 82ms/step - loss: 1.5555 - accuracy: 0.4769 - val_loss: 13.1176 - val_accuracy: 0.3363
# Epoch 10/20
# 57/57 [==============================] - ETA: 0s - loss: 1.4265 - accuracy: 0.4981
# Epoch 10: val_accuracy did not improve from 0.33630
# 57/57 [==============================] - 4s 63ms/step - loss: 1.4265 - accuracy: 0.4981 - val_loss: 20.6964 - val_accuracy: 0.1849
# Epoch 11/20
# 57/57 [==============================] - ETA: 0s - loss: 1.4495 - accuracy: 0.5047
# Epoch 11: val_accuracy did not improve from 0.33630
# 57/57 [==============================] - 4s 62ms/step - loss: 1.4495 - accuracy: 0.5047 - val_loss: 22.7219 - val_accuracy: 0.2539
# Epoch 12/20
# 57/57 [==============================] - ETA: 0s - loss: 1.2953 - accuracy: 0.5326
# Epoch 12: val_accuracy did not improve from 0.33630
# 57/57 [==============================] - 4s 62ms/step - loss: 1.2953 - accuracy: 0.5326 - val_loss: 11.1434 - val_accuracy: 0.2049
# Epoch 13/20
# 57/57 [==============================] - ETA: 0s - loss: 1.2119 - accuracy: 0.5470
# Epoch 13: val_accuracy improved from 0.33630 to 0.37862, saving model to model.h5
# 57/57 [==============================] - 5s 93ms/step - loss: 1.2119 - accuracy: 0.5470 - val_loss: 3.5432 - val_accuracy: 0.3786
# Epoch 14/20
# 57/57 [==============================] - ETA: 0s - loss: 1.2939 - accuracy: 0.5487
# Epoch 14: val_accuracy did not improve from 0.37862
# 57/57 [==============================] - 4s 64ms/step - loss: 1.2939 - accuracy: 0.5487 - val_loss: 17.9908 - val_accuracy: 0.2227
# Epoch 15/20
# 57/57 [==============================] - ETA: 0s - loss: 1.2732 - accuracy: 0.5448
# Epoch 15: val_accuracy did not improve from 0.37862
# 57/57 [==============================] - 3s 61ms/step - loss: 1.2732 - accuracy: 0.5448 - val_loss: 11.3049 - val_accuracy: 0.0935
# Epoch 16/20
# 57/57 [==============================] - ETA: 0s - loss: 1.6716 - accuracy: 0.4658
# Epoch 16: val_accuracy did not improve from 0.37862
# 57/57 [==============================] - 4s 62ms/step - loss: 1.6716 - accuracy: 0.4658 - val_loss: 23.2306 - val_accuracy: 0.1759
# Epoch 17/20
# 57/57 [==============================] - ETA: 0s - loss: 1.3182 - accuracy: 0.5147
# Epoch 17: val_accuracy did not improve from 0.37862
# 57/57 [==============================] - 4s 62ms/step - loss: 1.3182 - accuracy: 0.5147 - val_loss: 2.3999 - val_accuracy: 0.2361
# Epoch 18/20
# 57/57 [==============================] - ETA: 0s - loss: 1.2453 - accuracy: 0.5426
# Epoch 18: val_accuracy did not improve from 0.37862
# 57/57 [==============================] - 4s 62ms/step - loss: 1.2453 - accuracy: 0.5426 - val_loss: 3.7183 - val_accuracy: 0.2762
# Epoch 19/20
# 57/57 [==============================] - ETA: 0s - loss: 1.1698 - accuracy: 0.5843
# Epoch 19: val_accuracy did not improve from 0.37862
# 57/57 [==============================] - 4s 64ms/step - loss: 1.1698 - accuracy: 0.5843 - val_loss: 44.6270 - val_accuracy: 0.2027
# Epoch 20/20
# 57/57 [==============================] - ETA: 0s - loss: 1.1059 - accuracy: 0.5882
# Epoch 20: val_accuracy improved from 0.37862 to 0.41425, saving model to model.h5
# 57/57 [==============================] - 5s 82ms/step - loss: 1.1059 - accuracy: 0.5882 - val_loss: 2.1484 - val_accuracy: 0.4143

# %% [markdown]
# **Visualizing training results**

# %%
 acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Model Overfit or Underfit?**

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 57/57 [==============================] - 1s 20ms/step - loss: 1.4898 - accuracy: 0.5409
# 15/15 [==============================] - 0s 19ms/step - loss: 2.1484 - accuracy: 0.4143
# Accuracy:  0.5409014821052551
# Validation Accuracy:  0.4142538905143738
# Loss:  1.4898107051849365
# Validation Loss 2.148406982421875

# %% [markdown]
# Thus we can clearly say that model is Overfit and we need to chose right data augumentation strategy.

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(data_dir_train, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(data_dir_test, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)
# Out:
# Found 890 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %%
#Visualize one instance of all the class present in the dataset.

#image_dataset_from_directory() will return a tf.data.Dataset that yields batches of images from the subdirectories.
#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes), representing a one-hot encoding of the class index.
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),
                                                                    label_mode='categorical',seed=123)

#all the classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))
    
#Visualize image 
plt.figure(figsize=(10,10))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")



# visualize how your augmentation strategy works for one instance of training image.
#import matplotlib.pyplot as plt

#plt.figure(figsize=(10, 10))
#for images, labels in train_ds.take(1):
  #for i in range(9):
    #ax = plt.subplot(3, 3, i + 1)
    #plt.imshow(images[i].numpy().astype("uint8"))
    #plt.title(class_names[labels[i]])
    #plt.axis("off")
# Out:
# Found 2246 files belonging to 9 classes.

# %% [markdown]
# **Create the model, compile and train the model**

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

from keras.regularizers import l2

model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
# Adding Dropout Layer
model.add(Dropout(0.5))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_5 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 90, 90, 64)        18496
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 45, 45, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 43, 43, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 21, 21, 128)       0
#
#  flatten_1 (Flatten)         (None, 56448)             0
#
#  dense_2 (Dense)             (None, 512)               28901888
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 29,045,929
# Trainable params: 29,045,929
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compiling the model**

# %%
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# Using annealing method of the learning rate (LR) as it helps the optimizer converge faster and get closer to the global minimum of the loss function.

# %%
# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

# %% [markdown]
# **Training the model**

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
batch_size = 10
history = model.fit(train_batches,
  epochs = epochs, verbose = 1, validation_data=valid_batches , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/20
# 14/14 [==============================] - 66s 5s/step - loss: 389.7095 - accuracy: 0.3966 - val_loss: 3.6029 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.8734 - accuracy: 0.4787 - val_loss: 3.8120 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.7617 - accuracy: 0.4955 - val_loss: 3.8393 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/20
# 14/14 [==============================] - ETA: 0s - loss: 2.7578 - accuracy: 0.4528
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 [==============================] - 39s 3s/step - loss: 2.7578 - accuracy: 0.4528 - val_loss: 3.8281 - val_accuracy: 0.2917 - lr: 0.0010
# Epoch 5/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.7368 - accuracy: 0.4685 - val_loss: 3.8235 - val_accuracy: 0.3125 - lr: 5.0000e-04
# Epoch 6/20
# 14/14 [==============================] - 37s 3s/step - loss: 2.7240 - accuracy: 0.5090 - val_loss: 3.8144 - val_accuracy: 0.2917 - lr: 5.0000e-04
# Epoch 7/20
# 14/14 [==============================] - ETA: 0s - loss: 2.7241 - accuracy: 0.4697
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 [==============================] - 38s 3s/step - loss: 2.7241 - accuracy: 0.4697 - val_loss: 3.8050 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 8/20
# 14/14 [==============================] - 40s 3s/step - loss: 2.7061 - accuracy: 0.4809 - val_loss: 3.8009 - val_accuracy: 0.2917 - lr: 2.5000e-04
# Epoch 9/20
# 14/14 [==============================] - 39s 3s/step - loss: 2.6977 - accuracy: 0.5022 - val_loss: 3.7956 - val_accuracy: 0.3125 - lr: 2.5000e-04
# Epoch 10/20
# 14/14 [==============================] - ETA: 0s - loss: 2.6898 - accuracy: 0.4843
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 [==============================] - 38s 3s/step - loss: 2.6898 - accuracy: 0.4843 - val_loss: 3.7910 - val_accuracy: 0.2708 - lr: 2.5000e-04
# Epoch 11/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.6913 - accuracy: 0.4865 - val_loss: 3.7883 - val_accuracy: 0.2917 - lr: 1.2500e-04
# Epoch 12/20
# 14/14 [==============================] - 37s 3s/step - loss: 2.6803 - accuracy: 0.4719 - val_loss: 3.7843 - val_accuracy: 0.3125 - lr: 1.2500e-04
# Epoch 13/20
# 14/14 [==============================] - ETA: 0s - loss: 2.6736 - accuracy: 0.5011
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 14/14 [==============================] - 42s 3s/step - loss: 2.6736 - accuracy: 0.5011 - val_loss: 3.7819 - val_accuracy: 0.2917 - lr: 1.2500e-04
# Epoch 14/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.6819 - accuracy: 0.4798 - val_loss: 3.7817 - val_accuracy: 0.2917 - lr: 6.2500e-05
# Epoch 15/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.6355 - accuracy: 0.5315 - val_loss: 3.7780 - val_accuracy: 0.3125 - lr: 6.2500e-05
# Epoch 16/20
# 14/14 [==============================] - ETA: 0s - loss: 2.6770 - accuracy: 0.5022
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 14/14 [==============================] - 36s 3s/step - loss: 2.6770 - accuracy: 0.5022 - val_loss: 3.7776 - val_accuracy: 0.2500 - lr: 6.2500e-05
# Epoch 17/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.6689 - accuracy: 0.4944 - val_loss: 3.7777 - val_accuracy: 0.2917 - lr: 3.1250e-05
# Epoch 18/20
# 14/14 [==============================] - 39s 3s/step - loss: 2.6480 - accuracy: 0.5236 - val_loss: 3.7747 - val_accuracy: 0.2917 - lr: 3.1250e-05
# Epoch 19/20
# 14/14 [==============================] - ETA: 0s - loss: 2.6655 - accuracy: 0.4989
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 14/14 [==============================] - 38s 3s/step - loss: 2.6655 - accuracy: 0.4989 - val_loss: 3.7751 - val_accuracy: 0.2708 - lr: 3.1250e-05
# Epoch 20/20
# 14/14 [==============================] - 38s 3s/step - loss: 2.6646 - accuracy: 0.4933 - val_loss: 3.7745 - val_accuracy: 0.2708 - lr: 1.5625e-05

# %% [markdown]
# **Visualizing the results**

# %%
acc = history.history['accuracy']
print(history.history.keys, ":")
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# <built-in method keys of dict object at 0x7f36381d9a40> :

# %% [markdown]
# **Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?**
#
# Finding from Second Model
#
# There is no improvement in accuracy but we can definitely see the overfitting problem has solved due to data augmentation
#
# We can increase the epochs to increase the accuracy so it's too early for judgement
#
#
# **Todo: Find the distribution of classes in the training dataset.**
#
#
# ***Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data. ***

# %%
import matplotlib.pyplot as plt
data = dict()

for i in class_names:
  data[i] = []

#plt.figure(figsize=(10, 10))
#for images, labels in train_ds:
  #for i in range(9):
    #data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))
plt.figure(figsize=(10, 10))    
for images, labels in train_ds:
  for i in range(9):
    if i < len(labels):
      data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))
    else:
      break


for i in data:
  data[i] = len(data[i]) 

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(data)), list(data.values()), align='center')
plt.xticks(range(len(data)), list(data.keys()))
plt.show()

# %% [markdown]
.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030707.jpg_0c626869-933a-4610-a016-fe59a156e35c.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031874.jpg_7717bcb5-b15a-494f-8131-0adff0cbc304.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025790.jpg_a7ed43b8-7603-4a32-ac16-14c11563e7f3.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027084.jpg_2a344bd0-c769-4ffb-8528-6ab04897e0f3.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032349.jpg_c678ce9b-3e03-4b43-901d-e50745af6334.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029598.jpg_2fd6f186-72bb-4536-8816-30afc1d11053.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026992.jpg_78a72303-d602-4958-b59a-c14b56329cdb.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030991.jpg_e43957b7-69e4-4ba1-b6dc-2d4667e5c720.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028816.jpg_374638b3-dd2c-42e4-8710-bd8b8168db6a.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030076.jpg_58c1af26-e5d4-423e-bc15-f9aa08582ed9.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031672.jpg_4d5e2dab-dd5f-4709-98fe-1c5f8e8a1102.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029371.jpg_7cdb270a-0a78-4f4b-8b5a-afb80a95520c.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028381.jpg_d6fdd069-6170-41dd-a6b5-61693d9a0918.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026388.jpg_6a6d9e9f-99e1-408d-808a-83f2e30b26e4.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030591.jpg_0153f246-ab4d-4f9f-a0ff-75a26e5abd97.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029371.jpg_577d3850-d88c-4b72-8347-023d6281f4af.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028158.jpg_a14cf4a1-6fcc-4dd4-87c6-967b6aba7bff.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030076.jpg_4ec635a9-d461-4e3a-806b-836e84c47a0a.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029851.jpg_6e58025f-9d4d-4288-8236-bb5181e2d668.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025411.jpg_e16dfac8-767c-4489-b746-ec3f316edf73.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030487.jpg_4b12e98d-8411-4994-b285-7067d7e322a2.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030953.jpg_71844724-2991-4c75-8850-34cdb514bbca.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025696.jpg_6729f793-d83c-40aa-b8e2-4cb710423993.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032356.jpg_3d29f1c8-4ead-418c-ab33-361ae4d9841f.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025178.jpg_dae2eef1-9626-4279-a212-ea5500cd3fb7.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026362.jpg_7e07e990-1401-4819-bac0-5acb1af69222.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027084.jpg_7ee1f9eb-f8e4-4d5e-8798-6233439e5768.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029059.jpg_af36d1ff-0231-4732-9a24-83034056ce9c.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025948.jpg_ec63da98-dde7-41ba-972a-04ee6cdc29cc.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029541.jpg_37f90ee9-6614-434e-ba96-e9df80aa4515.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030991.jpg_c80ec64a-3d0a-45ba-8780-4ac768fc1f40.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032014.jpg_b50aa351-ef7b-4de5-aaee-de67d2e58a2b.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031874.jpg_cd92d24e-3f98-4901-9eed-959beabd6efa.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028372.jpg_d1bef99b-d9c3-4c7b-8282-fcad06b4d163.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031874.jpg_9e91b1f3-e410-48de-9844-5ad3614a3732.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027719.jpg_22a2b916-a350-4c64-b46e-ff79aecda181.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031927.jpg_695b5259-21a3-4dae-a84d-dbf3472c0144.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025696.jpg_3b0783a0-2579-4a0a-a134-741959a98448.jpg',
#  '/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032349.jpg_985955dc-55ab-4504-94ce-4868eb0bb9e5.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# actinic keratosis             500
# squamous cell carcinoma       500
# melanoma                      500
# vascular lesion               500
# dermatofibroma                500
# pigmented benign keratosis    500
# seborrheic keratosis          500
# nevus                         500
# basal cell carcinoma          500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# **Train the model on the data created using Augmentor**

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Create a training dataset**

# %%
data_dir_train="/content/gdrive/MyDrive/Assignments/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6746 files belonging to 9 classes.
# Using 5397 files for training.

# %% [markdown]
# **Create a validation dataset**

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6746 files belonging to 9 classes.
# Using 1349 files for validation.

# %% [markdown]
# **Create your model (make sure to include normalization)**

# %%
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_10 (Conv2D)          (None, 180, 180, 32)      9248
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 90, 90, 32)       128
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 90, 90, 64)        18496
#
#  conv2d_12 (Conv2D)          (None, 90, 90, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 45, 45, 64)       256
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 45, 45, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 43, 43, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 43, 43, 128)      512
#  hNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  dropout_7 (Dropout)         (None, 21, 21, 128)       0
#
#  flatten_2 (Flatten)         (None, 56448)             0
#
#  dense_4 (Dense)             (None, 128)               7225472
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 7,366,433
# Trainable params: 7,365,729
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# **Compile your model (Choose optimizer and loss function appropriately)**

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# **Train your model**

# %%
epochs = 50

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds,
  epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 169/169 [==============================] - 46s 243ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 0.0010
# Epoch 2/50
# 169/169 [==============================] - 39s 228ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 0.0010
# Epoch 3/50
# 169/169 [==============================] - 40s 228ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 0.0010
# Epoch 4/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1347
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 169/169 [==============================] - 40s 229ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 0.0010
# Epoch 5/50
# 169/169 [==============================] - 39s 227ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 5.0000e-04
# Epoch 6/50
# 169/169 [==============================] - 39s 227ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 5.0000e-04
# Epoch 7/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1347
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 169/169 [==============================] - 40s 228ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 5.0000e-04
# Epoch 8/50
# 169/169 [==============================] - 39s 227ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 2.5000e-04
# Epoch 9/50
# 169/169 [==============================] - 39s 227ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 2.5000e-04
# Epoch 10/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1347
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 169/169 [==============================] - 40s 230ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 2.5000e-04
# Epoch 11/50
# 169/169 [==============================] - 40s 231ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.2500e-04
# Epoch 12/50
# 169/169 [==============================] - 40s 228ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.2500e-04
# Epoch 13/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1347
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 169/169 [==============================] - 40s 229ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.2500e-04
# Epoch 14/50
# 169/169 [==============================] - 40s 230ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 6.2500e-05
# Epoch 15/50
# 169/169 [==============================] - 43s 244ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 6.2500e-05
# Epoch 16/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1347
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 169/169 [==============================] - 42s 242ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 6.2500e-05
# Epoch 17/50
# 169/169 [==============================] - 43s 249ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 3.1250e-05
# Epoch 18/50
# 169/169 [==============================] - 44s 251ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 3.1250e-05
# Epoch 19/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1347
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 169/169 [==============================] - 45s 260ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 3.1250e-05
# Epoch 20/50
# 169/169 [==============================] - 41s 236ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.5625e-05
# Epoch 21/50
# 169/169 [==============================] - 41s 235ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.5625e-05
# Epoch 22/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1347
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-05.
# 169/169 [==============================] - 40s 233ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.5625e-05
# Epoch 23/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 24/50
# 169/169 [==============================] - 40s 231ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 25/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 26/50
# 169/169 [==============================] - 41s 234ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 27/50
# 169/169 [==============================] - 41s 235ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 28/50
# 169/169 [==============================] - 41s 233ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 29/50
# 169/169 [==============================] - 44s 252ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 30/50
# 169/169 [==============================] - 40s 231ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 31/50
# 169/169 [==============================] - 40s 230ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 32/50
# 169/169 [==============================] - 42s 241ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 33/50
# 169/169 [==============================] - 46s 265ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 34/50
# 169/169 [==============================] - 41s 234ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 35/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 36/50
# 169/169 [==============================] - 41s 234ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 37/50
# 169/169 [==============================] - 40s 231ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 38/50
# 169/169 [==============================] - 40s 231ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 39/50
# 169/169 [==============================] - 41s 238ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 40/50
# 169/169 [==============================] - 45s 262ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 41/50
# 169/169 [==============================] - 41s 238ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 42/50
# 169/169 [==============================] - 41s 238ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 43/50
# 169/169 [==============================] - 42s 243ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 44/50
# 169/169 [==============================] - 47s 270ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 45/50
# 169/169 [==============================] - 41s 235ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 46/50
# 169/169 [==============================] - 41s 235ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 47/50
# 169/169 [==============================] - 41s 234ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 48/50
# 169/169 [==============================] - 40s 232ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 49/50
# 169/169 [==============================] - 40s 230ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05
# Epoch 50/50
# 169/169 [==============================] - 41s 236ms/step - loss: 0.0000e+00 - accuracy: 0.1347 - val_loss: 0.0000e+00 - val_accuracy: 0.1156 - lr: 1.0000e-05

# %% [markdown]
# **Visualize the model results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Did you get rid of underfitting/overfitting? Did class rebalance help?**
#
# The class rebalance helped in reducing overfititng of the data and thus the loass is beng reduced But it reduced the Acurracy very low
#
# Initially we tried without the ImageDataGenerator which created data to over fit at high ratio
#
# Then we introduced dropout and ImageDataGenerator which reduced the over fit
#
# At last we tried Batch Normalization and Augumentation which really helped in carry forward
